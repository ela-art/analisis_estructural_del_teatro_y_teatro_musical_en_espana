# %% [markdown]
# Este Dataset reune la info de musicales_limpio y añade/actualiza con la de musicales_listado

# %%
import pandas as pd

# %%
df_base = pd.read_csv("musicales_limpio.csv")
df_excel = pd.read_excel("musicales_listado.xlsx")

# %%
def normaliza_columnas(df):
    df = df.copy()
    df.columns = (
        df.columns
          .str.strip()        # quita espacios al inicio y al final
          .str.lower()        # pasa todo a minúsculas
          .str.replace(" ", "_")  # espacios -> guiones bajos
    )
    return df

df_base = normaliza_columnas(df_base)
df_excel = normaliza_columnas(df_excel)

# %%
def normaliza_nombres(df):
    df = df.copy()
    df.columns = (
        df.columns
          .str.strip()
          .str.lower()
          .str.replace(" ", "_")
          .str.replace("__", "_")
    )
    return df

# 1) Normalizar NOMBRES justo después de cargar
df_base  = normaliza_nombres(df_base)
df_excel = normaliza_nombres(df_excel)

# 2) Crear clave compuesta
def crear_clave(df):
    return (
        df["obra"].astype(str).str.strip().str.lower() + " | " +
        df["productora"].astype(str).str.strip().str.lower() + " | " +
        df["anio_inicio"].astype(str).str.strip() + " | " +
        df["anio_fin"].astype(str).str.strip()
    )

df_base["clave_prod"]  = crear_clave(df_base)
df_excel["clave_prod"] = crear_clave(df_excel)

base_idx  = df_base.set_index("clave_prod")
excel_idx = df_excel.set_index("clave_prod")

base_idx.update(excel_idx)

claves_nuevas = excel_idx.index.difference(base_idx.index)
df_nuevos = excel_idx.loc[claves_nuevas]

df_final = pd.concat([base_idx, df_nuevos]).reset_index()

# %%
df = df_final.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   clave_prod        75 non-null     object
#  1   obra              75 non-null     object
#  2   productora        75 non-null     object
#  3   anio_inicio       75 non-null     int64
#  4   anio_fin          62 non-null     float64
#  5   teatro            75 non-null     object
#  6   ciudad_principal  75 non-null     object
#  7   gira              75 non-null     object
#  8   fuente_url        75 non-null     object
#  9   activa            75 non-null     object
#  10  duracion          62 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 6.6+ KB

# %%
df.head(20)
# Out:
#                                            clave_prod  \
# 0   101 dálmatas, el musical | teatropolis (gran t...
# 1       aladdín | stage entertainment | 2023 | 2025.0
# 2     anastasia | stage entertainment | 2018 | 2020.0
# 3   avenue q | teatropolis (gran teatro caixabank ...
# 4          billy elliot | som produce | 2017 | 2020.0
# 5             cabaret | let's go company | 2025 | nan
# 6       cenicienta | stage entertainment | 2025 | nan
# 7   charlie y la fábrica de chocolate | let's go c...
# 8               chicago | som produce | 2023 | 2025.0
# 9    dirty dancing | let's go company | 2018 | 2023.0
# 10  el día de la marmota | nostromo live | 2024 | ...
# 11  el fantasma de la ópera | let's go company | 2...
# 12  el guardaespaldas | stage entertainment | 2017...
# 13  el jovencito frankenstein | let's go company |...
# 14     el médico | beon entertainment | 2018 | 2023.0
# 15     el rey león | stage entertainment | 2011 | nan
# 16  el tiempo entre costuras | beon entertainment ...
# 17  ghost, el musical | let's go company | 2019 | ...
# 18               grease | som produce | 2021 | 2023.0
# 19            houdini | let's go company | 2025 | nan
#
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                            Avenue Q
# 4                        Billy Elliot
# 5                             Cabaret
# 6                          Cenicienta
# 7   Charlie y la fábrica de chocolate
# 8                             Chicago
# 9                       Dirty Dancing
# 10               El Día de la Marmota
# 11            El Fantasma de la Ópera
# 12                  El Guardaespaldas
# 13          El Jovencito Frankenstein
# 14                          El Médico
# 15                        El Rey León
# 16           El Tiempo entre Costuras
# 17                  Ghost, el musical
# 18                             Grease
# 19                            Houdini
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 1                                Stage Entertainment         2023    2025.0
# 2                                Stage Entertainment         2018    2020.0
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                        SOM Produce         2017    2020.0
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 7                                   Let's Go Company         2021    2022.0
# 8                                        SOM Produce         2023    2025.0
# 9                                   Let's Go Company         2018    2023.0
# 10                                     Nostromo Live         2024    2025.0
# 11                                  Let's Go Company         2023       NaN
# 12                               Stage Entertainment         2017    2018.0
# 13                                  Let's Go Company         2018    2019.0
# 14                                Beon Entertainment         2018    2023.0
# 15                               Stage Entertainment         2011       NaN
# 16                                Beon Entertainment         2021    2024.0
# 17                                  Let's Go Company         2019    2024.0
# 18                                       SOM Produce         2021    2023.0
# 19                                  Let's Go Company         2025       NaN
#
#                                 teatro ciudad_principal gira  \
# 0   Gran Teatro CaixaBank Príncipe Pío           Madrid   No
# 1                      Teatro Coliseum           Madrid   No
# 2                      Teatro Coliseum           Madrid   No
# 3   Gran Teatro CaixaBank Príncipe Pío           Madrid   No
# 4                  Nuevo Teatro Alcalá           Madrid   Sí
# 5                              Albéniz           Madrid   No
# 6                             Coliseum           Madrid   No
# 7            Espacio Ibercaja Delicias           Madrid   Sí
# 8                         Teatro Apolo           Madrid   Sí
# 9                  Teatro Nuevo Alcalá           Madrid   Sí
# 10               Teatro Coliseum (BCN)        Barcelona   No
# 11         UMusic Hotel Teatro Albéniz           Madrid   Sí
# 12                     Teatro Coliseum           Madrid   Sí
# 13                     Teatro Gran Vía           Madrid   No
# 14                  Teatro Nuevo Apolo           Madrid   Sí
# 15                 Teatro Lope de Vega           Madrid   No
# 16        Teatro Principal de Zaragoza           Madrid   Sí
# 17                 Teatro EDP Gran Vía           Madrid   Sí
# 18                 Nuevo Teatro Alcalá           Madrid   Sí
# 19                     Teatro Calderón           Madrid   No
#
#                                            fuente_url activa  duracion
# 0     https://www.granteatrocaixabankprincipepio.com/   True       NaN
# 1             https://www.stage.es/musicales/aladdin/  False       2.0
# 2           https://www.stage.es/musicales/anastasia/  False       2.0
# 3              https://es.wikipedia.org/wiki/Avenue_Q   True       NaN
# 4      https://somproduce.com/musicales/billy-elliot/  False       3.0
# 5                        fuente: observación personal   True       NaN
# 6                        fuente: observación personal   True       NaN
# 7   https://www.teatroalamedia.com/charlie-y-la-fa...  False       1.0
# 8           https://somproduce.com/musicales/chicago/  False       2.0
# 9      https://www.entradas.com/artist/dirty-dancing/  False       5.0
# 10  https://www.nostromolive.com/espectaculos/el-d...  False       1.0
# 11  https://www.stage-entertainment.es/musicales/e...   True       NaN
# 12  https://es.wikipedia.org/wiki/El_Guardaespalda...  False       1.0
# 13  https://letsgo.es/espectaculos/el-jovencito-fr...  False       1.0
# 14  https://www.beonworldwide.com/proyectos/el-med...  False       5.0
# 15        https://www.stage.es/musicales/el-rey-leon/   True       NaN
# 16  https://www.beonworldwide.com/proyectos/el-tie...  False       3.0
# 17      https://www.lacoctelera.com/ghost-el-musical/  False       5.0
# 18           https://somproduce.com/musicales/grease/  False       2.0
# 19                  https://www.houdinielmusical.com/   True       NaN

# %%
df.duplicated(subset=["obra", "productora", "anio_inicio", "anio_fin"]).sum()
# Out:
# np.int64(0)

# %%
df[["obra", "productora", "anio_inicio", "anio_fin"]].isna().sum()
# Out:
# obra            0
# productora      0
# anio_inicio     0
# anio_fin       13
# dtype: int64

# %%
df[df["anio_fin"].isna()][["obra", "productora", "anio_inicio", "anio_fin"]]
# Out:
#                         obra  \
# 0   101 Dálmatas, el musical
# 3                   Avenue Q
# 5                    Cabaret
# 6                 Cenicienta
# 11   El Fantasma de la Ópera
# 15               El Rey León
# 19                   Houdini
# 26                La Llamada
# 27            Los Miserables
# 28  Los Pilares de la Tierra
# 30                Mamma Mia!
# 36        The Book of Mormon
# 40          We Will Rock You
#
#                                           productora  anio_inicio  anio_fin
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 11                                  Let's Go Company         2023       NaN
# 15                               Stage Entertainment         2011       NaN
# 19                                  Let's Go Company         2025       NaN
# 26                           Suma Latina / Los Javis         2013       NaN
# 27                                       SOM Produce         2025       NaN
# 28                                Beon Entertainment         2024       NaN
# 30                                       SOM Produce         2022       NaN
# 36                                       SOM Produce         2023       NaN
# 40  Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN

# %%
mask_hair = (
    df["obra"].astype(str).str.strip().str.lower() == "hair"
) & (
    df["productora"].astype(str).str.lower().str.contains("william morris")
) & (
    df["teatro"].astype(str).str.lower().str.contains("apolo")
)

# Poner año fin 2011
df.loc[mask_hair, "anio_fin"] = 2011

# Cambiar gira a "No"
df.loc[mask_hair, "gira"] = "No"

# %%
df.loc[
    df["obra"].str.lower().str.strip() == "hair",
    ["obra", "productora", "teatro", "anio_inicio", "anio_fin", "gira"]
]
# Out:
#     obra                                         productora teatro  \
# 58  Hair  The William Morris Agency Endeavor Entertainme...  Apolo
#
#     anio_inicio  anio_fin gira
# 58         2010    2011.0   No

# %%
df.loc[
    df["obra"].str.strip() == "La llamada",
    "anio_fin"
] = 2024

# %%
df.loc[
    df["obra"].str.strip().str.lower() == "la llamada",
    ["obra", "anio_inicio", "anio_fin"]
]
# Out:
#           obra  anio_inicio  anio_fin
# 26  La Llamada         2013       NaN
# 60  La llamada         2013    2024.0

# %%
mask_llamada = (
    df["obra"].str.strip().str.lower() == "la llamada"
) & (
    df["anio_inicio"] == 2013
)

# %%
df.loc[mask_llamada, "anio_fin"] = 2024

# %%
df[df["obra"].str.strip().str.lower() == "la llamada"]
# Out:
#                                            clave_prod        obra  \
# 26  la llamada | suma latina / los javis | 2013 | nan  La Llamada
# 60              la llamada | los javies | 2013 | 2024  La llamada
#
#                  productora  anio_inicio  anio_fin       teatro  \
# 26  Suma Latina / Los Javis         2013    2024.0  Teatro Lara
# 60               Los javies         2013    2024.0         Lara
#
#    ciudad_principal gira                                         fuente_url  \
# 26           Madrid   Sí  https://es.wikipedia.org/wiki/La_llamada_(musi...
# 60           Madrid   Si            La llamada (2013) - Cartelera Musicales
#
#    activa  duracion
# 26   True       NaN
# 60  False      95.0

# %%
# Eliminar la fila 26 y reindexar
df = df.drop(index=26).reset_index(drop=True)

# %%
df.loc[df["obra"].str.strip().str.lower() == "la llamada",
       ["obra", "anio_inicio", "anio_fin"]]
# Out:
#           obra  anio_inicio  anio_fin
# 59  La llamada         2013    2024.0

# %%
mask_llamada = df["obra"].str.strip().str.lower() == "la llamada"
df.loc[mask_llamada, "productora"] = "Los Javis"

# %%
df.loc[mask_llamada, ["obra", "productora"]]
# Out:
#           obra productora
# 59  La llamada  Los Javis

# %%
df[df["anio_fin"].isna()][["obra", "productora", "anio_inicio", "anio_fin"]]
# Out:
#                         obra  \
# 0   101 Dálmatas, el musical
# 3                   Avenue Q
# 5                    Cabaret
# 6                 Cenicienta
# 11   El Fantasma de la Ópera
# 15               El Rey León
# 19                   Houdini
# 26            Los Miserables
# 27  Los Pilares de la Tierra
# 29                Mamma Mia!
# 35        The Book of Mormon
# 39          We Will Rock You
#
#                                           productora  anio_inicio  anio_fin
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 11                                  Let's Go Company         2023       NaN
# 15                               Stage Entertainment         2011       NaN
# 19                                  Let's Go Company         2025       NaN
# 26                                       SOM Produce         2025       NaN
# 27                                Beon Entertainment         2024       NaN
# 29                                       SOM Produce         2022       NaN
# 35                                       SOM Produce         2023       NaN
# 39  Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN

# %%
df["duracion"] = pd.to_numeric(df["duracion"], errors="coerce")

# %%
df["duracion"] = pd.to_numeric(df["duracion"], errors="coerce")

# %%
mask_ok = df["duracion"].between(40, 240)

# %%
df.loc[~mask_ok, "duracion"] = pd.NA

# %%
df[df["duracion"].isna()][["obra", "productora", "anio_inicio", "duracion"]]
# Out:
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                            Avenue Q
# 4                        Billy Elliot
# 5                             Cabaret
# 6                          Cenicienta
# 7   Charlie y la fábrica de chocolate
# 8                             Chicago
# 9                       Dirty Dancing
# 10               El Día de la Marmota
# 11            El Fantasma de la Ópera
# 12                  El Guardaespaldas
# 13          El Jovencito Frankenstein
# 14                          El Médico
# 15                        El Rey León
# 16           El Tiempo entre Costuras
# 17                  Ghost, el musical
# 18                             Grease
# 19                            Houdini
# 20                        Kinky Boots
# 21                        Kinky Boots
# 22                La Alegría que Pasa
# 23                  La Familia Addams
# 24           La Historia Interminable
# 25              La Jaula de las Locas
# 26                     Los Miserables
# 27           Los Pilares de la Tierra
# 28                    Los Productores
# 29                         Mamma Mia!
# 30                            Matilda
# 31      Priscilla, reina del desierto
# 32        Romeo y Julieta, el musical
# 33                     School of Rock
# 34                         Sister Act
# 35                 The Book of Mormon
# 36         The Full Monty, el musical
# 37                           The Hole
# 38                               Tina
# 39                   We Will Rock You
# 40                         Mari i Cel
#
#                                           productora  anio_inicio  duracion
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 1                                Stage Entertainment         2023       NaN
# 2                                Stage Entertainment         2018       NaN
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                        SOM Produce         2017       NaN
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 7                                   Let's Go Company         2021       NaN
# 8                                        SOM Produce         2023       NaN
# 9                                   Let's Go Company         2018       NaN
# 10                                     Nostromo Live         2024       NaN
# 11                                  Let's Go Company         2023       NaN
# 12                               Stage Entertainment         2017       NaN
# 13                                  Let's Go Company         2018       NaN
# 14                                Beon Entertainment         2018       NaN
# 15                               Stage Entertainment         2011       NaN
# 16                                Beon Entertainment         2021       NaN
# 17                                  Let's Go Company         2019       NaN
# 18                                       SOM Produce         2021       NaN
# 19                                  Let's Go Company         2025       NaN
# 20                                  Let's Go Company         2021       NaN
# 21                                Theatre Properties         2024       NaN
# 22                                      Dagoll Dagom         2022       NaN
# 23                                  Let's Go Company         2017       NaN
# 24                                Beon Entertainment         2022       NaN
# 25                                     Nostromo Live         2018       NaN
# 26                                       SOM Produce         2025       NaN
# 27                                Beon Entertainment         2024       NaN
# 28                                     Nostromo Live         2023       NaN
# 29                                       SOM Produce         2022       NaN
# 30                                       SOM Produce         2022       NaN
# 31                                       SOM Produce         2014       NaN
# 32                                Theatre Properties         2021       NaN
# 33                                  Let's Go Company         2024       NaN
# 34                               Stage Entertainment         2015       NaN
# 35                                       SOM Produce         2023       NaN
# 36                                Theatre Properties         2022       NaN
# 37                                  Let's Go Company         2011       NaN
# 38                               Stage Entertainment         2021       NaN
# 39  Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 40                                      Dagoll Dagom         2024       NaN

# %%
nombres_0_15 = [
    "101 Dálmatas, el musical",
    "Aladdin",
    "Anastasia",
    "Avenue Q",
    "Billy Elliot",
    "Cabaret",
    "Cenicienta",
    "Charlie y la fábrica de chocolate",
    "Chicago",
    "Dirty Dancing",
    "El Día de la Marmota",
    "El Fantasma de la Ópera",
    "El Guardaspaldas",
    "El Jovencito Frankenstein",
    "El Médico",
    "El Rey León"
]

df[df["obra"].isin(nombres_0_15) & df["duracion"].isna()]
# Out:
#                                            clave_prod  \
# 0   101 dálmatas, el musical | teatropolis (gran t...
# 2     anastasia | stage entertainment | 2018 | 2020.0
# 3   avenue q | teatropolis (gran teatro caixabank ...
# 4          billy elliot | som produce | 2017 | 2020.0
# 5             cabaret | let's go company | 2025 | nan
# 6       cenicienta | stage entertainment | 2025 | nan
# 7   charlie y la fábrica de chocolate | let's go c...
# 8               chicago | som produce | 2023 | 2025.0
# 9    dirty dancing | let's go company | 2018 | 2023.0
# 10  el día de la marmota | nostromo live | 2024 | ...
# 11  el fantasma de la ópera | let's go company | 2...
# 13  el jovencito frankenstein | let's go company |...
# 14     el médico | beon entertainment | 2018 | 2023.0
# 15     el rey león | stage entertainment | 2011 | nan
#
#                                  obra  \
# 0            101 Dálmatas, el musical
# 2                           Anastasia
# 3                            Avenue Q
# 4                        Billy Elliot
# 5                             Cabaret
# 6                          Cenicienta
# 7   Charlie y la fábrica de chocolate
# 8                             Chicago
# 9                       Dirty Dancing
# 10               El Día de la Marmota
# 11            El Fantasma de la Ópera
# 13          El Jovencito Frankenstein
# 14                          El Médico
# 15                        El Rey León
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 2                                Stage Entertainment         2018    2020.0
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                        SOM Produce         2017    2020.0
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 7                                   Let's Go Company         2021    2022.0
# 8                                        SOM Produce         2023    2025.0
# 9                                   Let's Go Company         2018    2023.0
# 10                                     Nostromo Live         2024    2025.0
# 11                                  Let's Go Company         2023       NaN
# 13                                  Let's Go Company         2018    2019.0
# 14                                Beon Entertainment         2018    2023.0
# 15                               Stage Entertainment         2011       NaN
#
#                                 teatro ciudad_principal gira  \
# 0   Gran Teatro CaixaBank Príncipe Pío           Madrid   No
# 2                      Teatro Coliseum           Madrid   No
# 3   Gran Teatro CaixaBank Príncipe Pío           Madrid   No
# 4                  Nuevo Teatro Alcalá           Madrid   Sí
# 5                              Albéniz           Madrid   No
# 6                             Coliseum           Madrid   No
# 7            Espacio Ibercaja Delicias           Madrid   Sí
# 8                         Teatro Apolo           Madrid   Sí
# 9                  Teatro Nuevo Alcalá           Madrid   Sí
# 10               Teatro Coliseum (BCN)        Barcelona   No
# 11         UMusic Hotel Teatro Albéniz           Madrid   Sí
# 13                     Teatro Gran Vía           Madrid   No
# 14                  Teatro Nuevo Apolo           Madrid   Sí
# 15                 Teatro Lope de Vega           Madrid   No
#
#                                            fuente_url activa  duracion
# 0     https://www.granteatrocaixabankprincipepio.com/   True       NaN
# 2           https://www.stage.es/musicales/anastasia/  False       NaN
# 3              https://es.wikipedia.org/wiki/Avenue_Q   True       NaN
# 4      https://somproduce.com/musicales/billy-elliot/  False       NaN
# 5                        fuente: observación personal   True       NaN
# 6                        fuente: observación personal   True       NaN
# 7   https://www.teatroalamedia.com/charlie-y-la-fa...  False       NaN
# 8           https://somproduce.com/musicales/chicago/  False       NaN
# 9      https://www.entradas.com/artist/dirty-dancing/  False       NaN
# 10  https://www.nostromolive.com/espectaculos/el-d...  False       NaN
# 11  https://www.stage-entertainment.es/musicales/e...   True       NaN
# 13  https://letsgo.es/espectaculos/el-jovencito-fr...  False       NaN
# 14  https://www.beonworldwide.com/proyectos/el-med...  False       NaN
# 15        https://www.stage.es/musicales/el-rey-leon/   True       NaN

# %%
duraciones_oficiales = {
    "101 Dálmatas, el musical": 85,
    "Aladdín": 145,
    "Anastasia": 145,
    "Avenue Q": 100,
    "Billy Elliot": 150,
    "Cabaret": 150,
    "Cenicienta": 145,
    "Charlie y la fábrica de chocolate": 150,
    "Chicago": 150,
    "Dirty Dancing": 145,
    "El Día de la Marmota": 150,
    "El Fantasma de la Ópera": 150,
    "El Guardaspaldas": 125,
    "El Jovencito Frankenstein": 135,
    "El Médico": 170,
    "El Rey León": 165,
}

# Rellena solo donde está en NaN o vacío
df["duracion"] = df["duracion"].fillna(
    df["obra"].map(duraciones_oficiales)
)

# %%
df[df["duracion"].isna()][["obra", "productora", "anio_inicio", "duracion"]]
# Out:
#                              obra  \
# 12              El Guardaespaldas
# 16       El Tiempo entre Costuras
# 17              Ghost, el musical
# 18                         Grease
# 19                        Houdini
# 20                    Kinky Boots
# 21                    Kinky Boots
# 22            La Alegría que Pasa
# 23              La Familia Addams
# 24       La Historia Interminable
# 25          La Jaula de las Locas
# 26                 Los Miserables
# 27       Los Pilares de la Tierra
# 28                Los Productores
# 29                     Mamma Mia!
# 30                        Matilda
# 31  Priscilla, reina del desierto
# 32    Romeo y Julieta, el musical
# 33                 School of Rock
# 34                     Sister Act
# 35             The Book of Mormon
# 36     The Full Monty, el musical
# 37                       The Hole
# 38                           Tina
# 39               We Will Rock You
# 40                     Mari i Cel
#
#                                           productora  anio_inicio  duracion
# 12                               Stage Entertainment         2017       NaN
# 16                                Beon Entertainment         2021       NaN
# 17                                  Let's Go Company         2019       NaN
# 18                                       SOM Produce         2021       NaN
# 19                                  Let's Go Company         2025       NaN
# 20                                  Let's Go Company         2021       NaN
# 21                                Theatre Properties         2024       NaN
# 22                                      Dagoll Dagom         2022       NaN
# 23                                  Let's Go Company         2017       NaN
# 24                                Beon Entertainment         2022       NaN
# 25                                     Nostromo Live         2018       NaN
# 26                                       SOM Produce         2025       NaN
# 27                                Beon Entertainment         2024       NaN
# 28                                     Nostromo Live         2023       NaN
# 29                                       SOM Produce         2022       NaN
# 30                                       SOM Produce         2022       NaN
# 31                                       SOM Produce         2014       NaN
# 32                                Theatre Properties         2021       NaN
# 33                                  Let's Go Company         2024       NaN
# 34                               Stage Entertainment         2015       NaN
# 35                                       SOM Produce         2023       NaN
# 36                                Theatre Properties         2022       NaN
# 37                                  Let's Go Company         2011       NaN
# 38                               Stage Entertainment         2021       NaN
# 39  Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 40                                      Dagoll Dagom         2024       NaN

# %%
# Diccionario: título -> duración en minutos
dur_map = {
    "Aladdín": 145,
    "El Guardaespaldas": 160,
    "El Tiempo entre Costuras": 150,
    "Ghost, el musical": 150,
    "Grease": 150,
    "Houdini": 95,
    "Kinky Boots": 140,              # se aplicará a las dos filas con Kinky Boots que tengan NaN
    "La Alegría que Pasa": 105,
    "La Familia Addams": 150,
    "La Jaula de las Locas": 150,
    "Los Miserables": 170,
    "Los Pilares de la Tierra": 145,
    "Los Productores": 150,
    "Mamma Mia!": 155,
    "Matilda": 120,
    "Priscilla, reina del desierto": 150,
    "Romeo y Julieta, el musical": 130,
    "School of Rock": 160,
    "Sister Act": 120,
    "The Book of Mormon": 140,
    "The Full Monty, el musical": 150,
    "The Hole": 120,
    "Tina": 160,
    "We Will Rock You": 150,
    "Mar i Cel": 150,
}

# Rellenar solo donde duracion es NaN y el título coincide
for obra, mins in dur_map.items():
    mask = (
        df["obra"].str.strip().str.lower() == obra.lower()
    ) & df["duracion"].isna()
    df.loc[mask, "duracion"] = mins

# Comprobar que ya no quedan NaN en esos títulos
df[df["obra"].isin(dur_map.keys())][["obra", "anio_inicio", "duracion"]]
# Out:
#                              obra  anio_inicio  duracion
# 1                         Aladdín         2023     145.0
# 12              El Guardaespaldas         2017     160.0
# 16       El Tiempo entre Costuras         2021     150.0
# 17              Ghost, el musical         2019     150.0
# 18                         Grease         2021     150.0
# 19                        Houdini         2025      95.0
# 20                    Kinky Boots         2021     140.0
# 21                    Kinky Boots         2024     140.0
# 22            La Alegría que Pasa         2022     105.0
# 23              La Familia Addams         2017     150.0
# 25          La Jaula de las Locas         2018     150.0
# 26                 Los Miserables         2025     170.0
# 27       Los Pilares de la Tierra         2024     145.0
# 28                Los Productores         2023     150.0
# 29                     Mamma Mia!         2022     155.0
# 30                        Matilda         2022     120.0
# 31  Priscilla, reina del desierto         2014     150.0
# 32    Romeo y Julieta, el musical         2021     130.0
# 33                 School of Rock         2024     160.0
# 34                     Sister Act         2015     120.0
# 35             The Book of Mormon         2023     140.0
# 36     The Full Monty, el musical         2022     150.0
# 37                       The Hole         2011     120.0
# 38                           Tina         2021     160.0
# 39               We Will Rock You         2023     150.0
# 55                         Grease         2011     150.0
# 69                     Sister Act         2014     150.0

# %%
df["duracion"].isna().sum()
# Out:
# np.int64(2)

# %%
df[df["duracion"].isna()]
# Out:
#                                            clave_prod  \
# 24  la historia interminable | beon entertainment ...
# 40          mari i cel | dagoll dagom | 2024 | 2025.0
#
#                         obra          productora  anio_inicio  anio_fin  \
# 24  La Historia Interminable  Beon Entertainment         2022    2024.0
# 40                Mari i Cel        Dagoll Dagom         2024    2025.0
#
#              teatro ciudad_principal gira  \
# 24  Teatro Calderón           Madrid   Sí
# 40  Teatre Victòria        Barcelona   Sí
#
#                                            fuente_url activa  duracion
# 24  https://www.beonworldwide.com/proyectos/la-his...  False       NaN
# 40                      https://maricelelmusical.cat/  False       NaN

# %%
# La Historia Interminable (Beón)
df.loc[
    df["obra"].str.strip().str.lower() == "la historia interminable",
    "duracion"
] = 160

# Mar i Cel (Dagoll Dagom)
df.loc[
    df["obra"].str.strip().str.lower() == "mari i cel",
    "duracion"
] = 150

# %%
df["duracion"].isna().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=["obra", "productora"]).sum()
# Out:
# np.int64(1)

# %%
df[df["obra"].str.strip().str.lower() == "sister act"]
# Out:
#                                           clave_prod        obra  \
# 34  sister act | stage entertainment | 2015 | 2015.0  Sister Act
# 69    sister act | stage entertainment | 2014 | 2016  Sister Act
#
#              productora  anio_inicio  anio_fin               teatro  \
# 34  Stage Entertainment         2015    2015.0  Teatro Nuevo Alcalá
# 69  Stage Entertainment         2014    2016.0               Tívoli
#
#    ciudad_principal gira                                         fuente_url  \
# 34           Madrid   Sí  https://es.wikipedia.org/wiki/Sister_Act_(musi...
# 69        Barcelona   Si          https://www.stage.es/musicales/sister-act
#
#    activa  duracion
# 34  False     120.0
# 69  False     150.0

# %%
df = df.drop(index=34)

# %%
df[df["obra"].str.strip().str.lower() == "sister act"]
# Out:
#                                         clave_prod        obra  \
# 69  sister act | stage entertainment | 2014 | 2016  Sister Act
#
#              productora  anio_inicio  anio_fin  teatro ciudad_principal gira  \
# 69  Stage Entertainment         2014    2016.0  Tívoli        Barcelona   Si
#
#                                    fuente_url activa  duracion
# 69  https://www.stage.es/musicales/sister-act  False     150.0

# %%
df.info()
df["anio_fin"].isna().sum()
df["activa"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   clave_prod        73 non-null     object
#  1   obra              73 non-null     object
#  2   productora        73 non-null     object
#  3   anio_inicio       73 non-null     int64
#  4   anio_fin          61 non-null     float64
#  5   teatro            73 non-null     object
#  6   ciudad_principal  73 non-null     object
#  7   gira              73 non-null     object
#  8   fuente_url        73 non-null     object
#  9   activa            73 non-null     object
#  10  duracion          73 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 6.8+ KB
# activa
# False    32
# False    28
# True     12
# FaLse     1
# Name: count, dtype: int64

# %%
df["duracion"].describe()
# Out:
# count     73.000000
# mean     140.958904
# std       24.687738
# min       70.000000
# 25%      130.000000
# 50%      150.000000
# 75%      155.000000
# max      180.000000
# Name: duracion, dtype: float64

# %%
# Normalizar texto a minúsculas sin espacios
df["activa"] = (
    df["activa"]
    .astype(str)
    .str.strip()
    .str.lower()
    .map({"true": True, "false": False})
)

# Comprobar que ya es booleano
df["activa"].value_counts()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   clave_prod        73 non-null     object
#  1   obra              73 non-null     object
#  2   productora        73 non-null     object
#  3   anio_inicio       73 non-null     int64
#  4   anio_fin          61 non-null     float64
#  5   teatro            73 non-null     object
#  6   ciudad_principal  73 non-null     object
#  7   gira              73 non-null     object
#  8   fuente_url        73 non-null     object
#  9   activa            73 non-null     bool
#  10  duracion          73 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 6.3+ KB

# %%
df.groupby("activa")["obra"].count()
# Out:
# activa
# False    61
# True     12
# Name: obra, dtype: int64

# %%
df.loc[df["duracion"] == 70, ["obra", "productora", "anio_inicio", "duracion"]]
# Out:
#            obra      productora  anio_inicio  duracion
# 46  El ascensor  Actor’s First.         2017      70.0

# %%
sorted(df["productora"].dropna().unique())
# Out:
# ['ATG Entertainment',
#  'Actor’s First.',
#  'Arabian Horses Production LTD',
#  'Beon Entertainment',
#  'Beon Entertainment\n',
#  'Dagoll Dagom',
#  'Drive Entertainment',
#  'Euroscena',
#  'Ferran González & Alícia Serrat',
#  'Hatchwell Inversiones Musicales S.L.',
#  "Let's Go Company",
#  'Los Javis',
#  'Mario Gas',
#  'Nostromo Live',
#  'Nostromo live',
#  'Pentación Espectáculos\n',
#  'SMedia',
#  'SMedia\n',
#  'SOM Produce',
#  'Selladoor Worldwide',
#  'Smedia',
#  'Stage Entertainment',
#  'Stage Entertainment\n',
#  'Teatro del Soho S.L.',
#  'Teatro del Soho S.L.\n',
#  'Teatropolis (Gran Teatro CaixaBank Príncipe Pío)',
#  'The Stage Company',
#  'The William Morris Agency Endeavor Entertainment; Illuminati Production Group; Publintermedia Consulting; JK Productions',
#  'Theatre Properties',
#  'Theatre Properties\n',
#  'Tricicle']

# %%
# Normalizar productora
df["productora"] = (
    df["productora"]
    .astype(str)
    .str.replace(r"\s+", " ", regex=True)  # reemplaza espacios múltiples
    .str.replace("\n", "", regex=False)     # elimina saltos de línea
    .str.strip()                             # elimina espacios extremos
)

# Correcciones conocidas de variaciones
reemplazos = {
    "SMedia": "Smedia",
    "SMedia ": "Smedia",
    "Smedia\n": "Smedia",
    "Beon Entertainment\n": "Beon Entertainment",
    "Stage Entertainment\n": "Stage Entertainment",
    "Teatro del Soho S.L.\n": "Teatro del Soho S.L.",
    "Theatre Properties\n": "Theatre Properties",
}

df["productora"] = df["productora"].replace(reemplazos)

# Mostrar valores únicos ordenados
sorted(df["productora"].dropna().unique())
# Out:
# ['ATG Entertainment',
#  'Actor’s First.',
#  'Arabian Horses Production LTD',
#  'Beon Entertainment',
#  'Dagoll Dagom',
#  'Drive Entertainment',
#  'Euroscena',
#  'Ferran González & Alícia Serrat',
#  'Hatchwell Inversiones Musicales S.L.',
#  "Let's Go Company",
#  'Los Javis',
#  'Mario Gas',
#  'Nostromo Live',
#  'Nostromo live',
#  'Pentación Espectáculos',
#  'SOM Produce',
#  'Selladoor Worldwide',
#  'Smedia',
#  'Stage Entertainment',
#  'Teatro del Soho S.L.',
#  'Teatropolis (Gran Teatro CaixaBank Príncipe Pío)',
#  'The Stage Company',
#  'The William Morris Agency Endeavor Entertainment; Illuminati Production Group; Publintermedia Consulting; JK Productions',
#  'Theatre Properties',
#  'Tricicle']

# %%
df.loc[
    df["productora"].str.strip().str.lower() == "nostromo live",
    "productora"
] = "Nostromo Live"

# %%
df.loc[
    df["productora"].str.contains("som", case=False, na=False),
    "productora"
] = "ATG Entertainment"

# %%
sorted(df["productora"].dropna().unique())
# Out:
# ['ATG Entertainment',
#  'Actor’s First.',
#  'Arabian Horses Production LTD',
#  'Beon Entertainment',
#  'Dagoll Dagom',
#  'Drive Entertainment',
#  'Euroscena',
#  'Ferran González & Alícia Serrat',
#  'Hatchwell Inversiones Musicales S.L.',
#  "Let's Go Company",
#  'Los Javis',
#  'Mario Gas',
#  'Nostromo Live',
#  'Pentación Espectáculos',
#  'Selladoor Worldwide',
#  'Smedia',
#  'Stage Entertainment',
#  'Teatro del Soho S.L.',
#  'Teatropolis (Gran Teatro CaixaBank Príncipe Pío)',
#  'The Stage Company',
#  'The William Morris Agency Endeavor Entertainment; Illuminati Production Group; Publintermedia Consulting; JK Productions',
#  'Theatre Properties',
#  'Tricicle']

# %%
df.head(25)
# Out:
#                                            clave_prod  \
# 0   101 dálmatas, el musical | teatropolis (gran t...
# 1       aladdín | stage entertainment | 2023 | 2025.0
# 2     anastasia | stage entertainment | 2018 | 2020.0
# 3   avenue q | teatropolis (gran teatro caixabank ...
# 4          billy elliot | som produce | 2017 | 2020.0
# 5             cabaret | let's go company | 2025 | nan
# 6       cenicienta | stage entertainment | 2025 | nan
# 7   charlie y la fábrica de chocolate | let's go c...
# 8               chicago | som produce | 2023 | 2025.0
# 9    dirty dancing | let's go company | 2018 | 2023.0
# 10  el día de la marmota | nostromo live | 2024 | ...
# 11  el fantasma de la ópera | let's go company | 2...
# 12  el guardaespaldas | stage entertainment | 2017...
# 13  el jovencito frankenstein | let's go company |...
# 14     el médico | beon entertainment | 2018 | 2023.0
# 15     el rey león | stage entertainment | 2011 | nan
# 16  el tiempo entre costuras | beon entertainment ...
# 17  ghost, el musical | let's go company | 2019 | ...
# 18               grease | som produce | 2021 | 2023.0
# 19            houdini | let's go company | 2025 | nan
# 20     kinky boots | let's go company | 2021 | 2022.0
# 21   kinky boots | theatre properties | 2024 | 2025.0
# 22  la alegría que pasa | dagoll dagom | 2022 | 20...
# 23  la familia addams | let's go company | 2017 | ...
# 24  la historia interminable | beon entertainment ...
#
#                                  obra  \
# 0            101 Dálmatas, el musical
# 1                             Aladdín
# 2                           Anastasia
# 3                            Avenue Q
# 4                        Billy Elliot
# 5                             Cabaret
# 6                          Cenicienta
# 7   Charlie y la fábrica de chocolate
# 8                             Chicago
# 9                       Dirty Dancing
# 10               El Día de la Marmota
# 11            El Fantasma de la Ópera
# 12                  El Guardaespaldas
# 13          El Jovencito Frankenstein
# 14                          El Médico
# 15                        El Rey León
# 16           El Tiempo entre Costuras
# 17                  Ghost, el musical
# 18                             Grease
# 19                            Houdini
# 20                        Kinky Boots
# 21                        Kinky Boots
# 22                La Alegría que Pasa
# 23                  La Familia Addams
# 24           La Historia Interminable
#
#                                           productora  anio_inicio  anio_fin  \
# 0   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2023       NaN
# 1                                Stage Entertainment         2023    2025.0
# 2                                Stage Entertainment         2018    2020.0
# 3   Teatropolis (Gran Teatro CaixaBank Príncipe Pío)         2024       NaN
# 4                                  ATG Entertainment         2017    2020.0
# 5                                   Let's Go Company         2025       NaN
# 6                                Stage Entertainment         2025       NaN
# 7                                   Let's Go Company         2021    2022.0
# 8                                  ATG Entertainment         2023    2025.0
# 9                                   Let's Go Company         2018    2023.0
# 10                                     Nostromo Live         2024    2025.0
# 11                                  Let's Go Company         2023       NaN
# 12                               Stage Entertainment         2017    2018.0
# 13                                  Let's Go Company         2018    2019.0
# 14                                Beon Entertainment         2018    2023.0
# 15                               Stage Entertainment         2011       NaN
# 16                                Beon Entertainment         2021    2024.0
# 17                                  Let's Go Company         2019    2024.0
# 18                                 ATG Entertainment         2021    2023.0
# 19                                  Let's Go Company         2025       NaN
# 20                                  Let's Go Company         2021    2022.0
# 21                                Theatre Properties         2024    2025.0
# 22                                      Dagoll Dagom         2022    2023.0
# 23                                  Let's Go Company         2017    2018.0
# 24                                Beon Entertainment         2022    2024.0
#
#                                 teatro ciudad_principal gira  \
# 0   Gran Teatro CaixaBank Príncipe Pío           Madrid   No
# 1                      Teatro Coliseum           Madrid   No
# 2                      Teatro Coliseum           Madrid   No
# 3   Gran Teatro CaixaBank Príncipe Pío           Madrid   No
# 4                  Nuevo Teatro Alcalá           Madrid   Sí
# 5                              Albéniz           Madrid   No
# 6                             Coliseum           Madrid   No
# 7            Espacio Ibercaja Delicias           Madrid   Sí
# 8                         Teatro Apolo           Madrid   Sí
# 9                  Teatro Nuevo Alcalá           Madrid   Sí
# 10               Teatro Coliseum (BCN)        Barcelona   No
# 11         UMusic Hotel Teatro Albéniz           Madrid   Sí
# 12                     Teatro Coliseum           Madrid   Sí
# 13                     Teatro Gran Vía           Madrid   No
# 14                  Teatro Nuevo Apolo           Madrid   Sí
# 15                 Teatro Lope de Vega           Madrid   No
# 16        Teatro Principal de Zaragoza           Madrid   Sí
# 17                 Teatro EDP Gran Vía           Madrid   Sí
# 18                 Nuevo Teatro Alcalá           Madrid   Sí
# 19                     Teatro Calderón           Madrid   No
# 20  Espacio Delicias / Teatro Calderón           Madrid   No
# 21                       Teatro Rialto             Gira   Sí
# 22                    Teatre Poliorama        Barcelona   Sí
# 23                     Teatro Calderón           Madrid   Sí
# 24                     Teatro Calderón           Madrid   Sí
#
#                                            fuente_url  activa  duracion
# 0     https://www.granteatrocaixabankprincipepio.com/    True      85.0
# 1             https://www.stage.es/musicales/aladdin/   False     145.0
# 2           https://www.stage.es/musicales/anastasia/   False     145.0
# 3              https://es.wikipedia.org/wiki/Avenue_Q    True     100.0
# 4      https://somproduce.com/musicales/billy-elliot/   False     150.0
# 5                        fuente: observación personal    True     150.0
# 6                        fuente: observación personal    True     145.0
# 7   https://www.teatroalamedia.com/charlie-y-la-fa...   False     150.0
# 8           https://somproduce.com/musicales/chicago/   False     150.0
# 9      https://www.entradas.com/artist/dirty-dancing/   False     145.0
# 10  https://www.nostromolive.com/espectaculos/el-d...   False     150.0
# 11  https://www.stage-entertainment.es/musicales/e...    True     150.0
# 12  https://es.wikipedia.org/wiki/El_Guardaespalda...   False     160.0
# 13  https://letsgo.es/espectaculos/el-jovencito-fr...   False     135.0
# 14  https://www.beonworldwide.com/proyectos/el-med...   False     170.0
# 15        https://www.stage.es/musicales/el-rey-leon/    True     165.0
# 16  https://www.beonworldwide.com/proyectos/el-tie...   False     150.0
# 17      https://www.lacoctelera.com/ghost-el-musical/   False     150.0
# 18           https://somproduce.com/musicales/grease/   False     150.0
# 19                  https://www.houdinielmusical.com/    True      95.0
# 20  https://es.wikipedia.org/wiki/Kinky_Boots_(mus...   False     140.0
# 21         https://theatreproperties.com/kinky-boots/   False     140.0
# 22  https://www.dagolldagom.com/espectacle/la-aleg...   False     105.0
# 23  https://www.entradas.com/artist/la-familia-add...   False     150.0
# 24  https://www.beonworldwide.com/proyectos/la-his...   False     160.0

# %%
df.to_csv("maestro_musicales.csv", index=False, encoding="utf-8")
